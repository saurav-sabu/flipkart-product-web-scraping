# %% [markdown]
# # Problem Statement: Web Scraping Product Information from Flipkart
#
# **Background:**
#
# Flipkart is an e-commerce platform where users can search for and purchase various products. It contains a vast catalog of products with details such as product names, prices, sellers, and additional specifications. To gather data for analysis or other purposes, it can be valuable to extract specific product information from Flipkart's website programmatically.
#
# **Objective:**
#
# The objective of this project is to create a Python script that performs web scraping on Flipkart's website to extract essential information about Samsung mobile phone and store it for further analysis or use.

# %%
# Import necessary libraries
import pandas as pd
import requests
import numpy as np
from bs4 import BeautifulSoup

# %%
# Define functions to extract title
def get_title(soup):
    
    try:
        # Extract and clean the product title
        title_value = soup.find("span",class_="B_NuCI").text.replace("\xa0","")
    except:
        # If the title is not found, set it as an empty string
        title_value = ""
        
    return title_value

# %%
# Define functions to extract price
def get_price(soup):
    
    try:
        # Extract the product price
        price_value = soup.find("div",class_="_30jeq3 _16Jk6d").text
    except:
        # If the price is not found, set it as an empty string
        price_value = ""
    
    return price_value

# %%
# Define functions to extract rating
def get_rating(soup):
    
    try:
        # Extract the product rating
        rating_value = soup.find("div",class_="_3LWZlK").text
    except:
        # If the rating is not found, set it as an empty string
        rating_value = ""
    
    return rating_value

# %%
# Define functions to extract number of reviews
def get_num_review(soup):
    
    try:
        # Extract the number of reviews
        reviews_value = soup.find("span",class_="_2_R_DZ").find_all("span")[3].text.replace("\xa0","")
    except:
        # If the number of reviews is not found, set it as an empty string
        reviews_value = ""
    
    return reviews_value

# %%
# Define functions to extract product color
def get_color(soup):
    
    try:
        # Extract the product color
        color_value = soup.find_all("tr",class_="_1s_Smc row")[3].find("li",class_="_21lJbe").text
    except:
        # If the color is not found, set it as an empty string
        color_value = ""
    
    return color_value

# %%
# Define functions to extract product display size
def get_display_size(soup):
    
    try:
        # Extract the product display size
        display_value = soup.find_all("tr",class_="_1s_Smc row")[9].find("li",class_="_21lJbe").text
    except:
        # If the display size is not found, set it as an empty string
        display_value = ""
    
    return display_value

# %%
# Set the user-agent headers for HTTP requests
HEADERS = {"User-Agent":'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36'}

# %%
# Define the URL for Flipkart's Samsung product search
URL = "https://www.flipkart.com/search?q=samsung&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

# %%
# Send an HTTP GET request to the search page
response = requests.get(URL,headers=HEADERS)

# %%
# Print the HTTP response object
response
# Out:
# <Response [200]>

# %%
# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content,"html.parser")

# %%
# Find all product links on the search results page
links = soup.find_all("a",class_="s1Q9rs")

# %%
# Create an empty list to store product URLs
links_list = []

# %%
# Extract product URLs and store them in the list
for link in links:
    links_list.append(link.get("href"))

# %%
# Create a dictionary to store scraped data
d = {"title":[],"price":[],"rating":[],"num_review":[],"color":[],"display":[]}

# %%
# Iterate through product URLs and scrape data
for link in links_list:
    
    # Create the full URL for the product page
    new_webpage_URL = "https://www.flipkart.com" + link
    
    # Send an HTTP GET request to the product page and parse the HTML content
    new_response = requests.get(new_webpage_URL,headers=HEADERS)
    new_soup = BeautifulSoup(new_response.content,"html.parser")
    
    # Call the defined functions to extract and append data to the dictionary
    d["title"].append(get_title(new_soup))
    d["price"].append(get_price(new_soup))
    d["rating"].append(get_rating(new_soup))
    d["num_review"].append(get_num_review(new_soup))
    d["color"].append(get_color(new_soup))
    d["display"].append(get_display_size(new_soup))

# %%
# Create a DataFrame from the scraped data
df = pd.DataFrame(d)

# Replace empty strings in the "title" column with NaN and drop rows with NaN values in the "title" column
df["title"].replace("",np.nan,inplace=True)
df = df.dropna(subset=["title"])

# %%
# Display the DataFrame
df
# Out:
#                                                 title    price rating  \
# 0   Samsung Galaxy S21 FE 5G with Snapdragon 888 (...  ₹45,999    4.3
# 1   SAMSUNG 10000 mAh Power Bank (25 W, Fast Charg...   ₹1,999    4.3
# 2    SAMSUNG Galaxy F04 (Opal Green, 64 GB)(4 GB RAM)   ₹6,499    4.2
# 3   SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)(4 G...   ₹9,199    4.3
# 4   SAMSUNG Galaxy F04 (Jade Purple, 64 GB)(4 GB RAM)   ₹6,499    4.2
# 6   SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)(4 G...   ₹9,199    4.3
# 7   SAMSUNG Original 25W, Type C Power Adaptor com...   ₹1,299    4.4
# 8   SAMSUNG Galaxy F14 5G (B.A.E. Purple, 128 GB)(...  ₹12,490    4.2
# 9                         SAMSUNG Guru Music 2(Black)   ₹2,832    4.3
# 11  SAMSUNG Galaxy M14 5G (Smoky Teal, 128 GB)(6 G...  ₹13,484    4.2
# 12  SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)(6 GB...  ₹12,490    4.2
# 13  SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)(4 ...  ₹10,199    4.3
# 14  SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)(4 ...  ₹10,199    4.3
# 15  SAMSUNG Galaxy F34 5G (Electric Black, 128 GB)...  ₹16,499    4.2
# 16                         SAMSUNG Guru Music 2(Gold)   ₹2,880    4.3
# 17  SAMSUNG Galaxy M04 (Light Green, 64 GB)(4 GB RAM)   ₹7,112    4.1
# 19                         SAMSUNG Guru Music 2(Gold)   ₹2,880    4.3
# 20  SAMSUNG Galaxy M14 5G (Icy Silver, 128 GB)(6 G...  ₹13,965    4.2
# 21  SAMSUNG Galaxy F34 5G (Electric Black, 128 GB)...  ₹18,499    4.2
# 22               SAMSUNG Guru Music 2 SM-B315E(Black)   ₹2,832    4.1
# 23  SAMSUNG Galaxy F34 5G (Mystic Green, 128 GB)(6...  ₹16,499    4.2
# 24  SAMSUNG Galaxy F14 5G (B.A.E. Purple, 128 GB)(...  ₹11,490    4.2
# 25  SAMSUNG Galaxy M14 5G (Berry Blue, 128 GB)(4 G...  ₹12,928    4.2
# 26  SAMSUNG Galaxy M14 5G (Icy Silver, 128 GB)(6 G...  ₹13,796    4.2
# 27  SAMSUNG Galaxy M14 5G (Smoky Teal, 128 GB)(4 G...  ₹12,989    4.2
# 28  SAMSUNG Galaxy M14 5G (Berry Blue, 128 GB)(6 G...  ₹13,332    4.2
# 30    SAMSUNG Galaxy M04 (Dark Blue, 64 GB)(4 GB RAM)   ₹7,120    4.1
# 31  SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)(6 G...  ₹12,490    4.2
# 32  SAMSUNG Galaxy M14 5G (ICY Silver, 128 GB)(4 G...  ₹13,180    4.2
# 33  SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)(6 GB...  ₹15,499    4.3
# 34                        SAMSUNG Guru Music 2(White)   ₹2,349    4.3
# 35  SAMSUNG Galaxy F34 5G (Orchid Violet, 128 GB)(...  ₹16,499    4.2
# 36                        SAMSUNG GURU MUSIC 2(Black)   ₹2,699    4.1
# 37  SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)(4 GB...  ₹11,490    4.2
# 38  SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)(4 G...  ₹11,490    4.2
# 39  SAMSUNG Galaxy M33 5G (Deep Ocean Blue, 128 GB...  ₹17,390    4.2
#
#         num_review                      color  \
# 0    7,441 Reviews                      Olive
# 1       79 Reviews                          2
# 2    2,690 Reviews                 Opal Green
# 3    9,973 Reviews             Sunrise Copper
# 4    2,690 Reviews                Jade Purple
# 6    9,973 Reviews             Nightsky Green
# 7    6,606 Reviews  Travel Adapter (EP-TA800)
# 8    2,986 Reviews              B.A.E. Purple
# 9   19,158 Reviews                      Black
# 11     294 Reviews                 Smoky Teal
# 12   2,986 Reviews                  OMG Black
# 13   9,973 Reviews             Waterfall Blue
# 14   9,973 Reviews             Nightsky Green
# 15     457 Reviews             Electric Black
# 16  19,158 Reviews                       Gold
# 17     410 Reviews                Light Green
# 19  19,158 Reviews                       Gold
# 20     294 Reviews                 Icy Silver
# 21     136 Reviews             Electric Black
# 22     747 Reviews                      Black
# 23     457 Reviews               Mystic Green
# 24   1,108 Reviews              B.A.E. Purple
# 25     105 Reviews                 Berry Blue
# 26     294 Reviews                 Icy Silver
# 27     105 Reviews                 Smoky Teal
# 28     294 Reviews                 Berry Blue
# 30     410 Reviews                  Dark Blue
# 31   2,986 Reviews                 GOAT Green
# 32     105 Reviews                 ICY Silver
# 33  16,067 Reviews                  Aqua Blue
# 34  19,158 Reviews                      White
# 35     457 Reviews              Orchid Violet
# 36     361 Reviews                      Black
# 37   1,108 Reviews                  OMG Black
# 38   1,108 Reviews                 GOAT Green
# 39     292 Reviews            Deep Ocean Blue
#
#                                               display
# 0                                                 Yes
# 1   Surge Damages and Battery Damages will Not Cov...
# 2                                 16.51 cm (6.5 inch)
# 3                                 16.76 cm (6.6 inch)
# 4                                 16.51 cm (6.5 inch)
# 6                                 16.76 cm (6.6 inch)
# 7                                      Samsung phones
# 8                                 16.76 cm (6.6 inch)
# 9                                                 Yes
# 11  Data Cable (USB TypeC to C), Ejection Pin, Use...
# 12                                16.76 cm (6.6 inch)
# 13                                16.76 cm (6.6 inch)
# 14                                16.76 cm (6.6 inch)
# 15                                                Yes
# 16                                   5.08 cm (2 inch)
# 17                                16.51 cm (6.5 inch)
# 19                                   5.08 cm (2 inch)
# 20  ?Type-C Data Cable, Quick Start Guide, Sim Eje...
# 21                                                Yes
# 22                                               QVGA
# 23                                                Yes
# 24                                16.76 cm (6.6 inch)
# 25  Type-C Data Cable, Quick Start Guide, Sim Ejec...
# 26  ?Type-C Data Cable, Quick Start Guide, Sim Eje...
# 27  Type-C Data Cable, Quick Start Guide, Sim Ejec...
# 28  Type-C Data Cable, Quick Start Guide, Sim Ejec...
# 30           USB Cable, Adaptor, Ejection Pin, Manual
# 31                                16.76 cm (6.6 inch)
# 32  Type-C Data Cable, Quick Start Guide, Sim Ejec...
# 33                                                Yes
# 34                                                 No
# 35                                                Yes
# 36                                                 No
# 37                                16.76 cm (6.6 inch)
# 38                                16.76 cm (6.6 inch)
# 39                                16.76 cm (6.6 inch)

# %%
# Save the DataFrame to a CSV file
df.to_csv("Flipkart_samsung_phone_data.csv", index=False)
